# %% [markdown]
# # Adding Clusters, Regions to the intermediate dataset

# %%
import numpy as np
import pandas as pd
import math

# %%
data = pd.read_csv("finaldata.csv")

# %%
clusresult = pd.read_csv("cluster results.csv")

# %% [markdown]
# ## Understanding and checking for any data problems

# %%
clusresult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  350 non-null    int64
#  1   STATE                       350 non-null    object
#  2   Year                        350 non-null    int64
#  3   CO2                         350 non-null    int64
#  4   CH4                         350 non-null    int64
#  5   N2O                         350 non-null    int64
#  6   Fluorinated GHG             112 non-null    float64
#  7   Laws and Regulations        350 non-null    int64
#  8   State Incentives            350 non-null    int64
#  9   Utility/Private Incentives  350 non-null    int64
#  10  Ozone                       350 non-null    float64
#  11  cluster                     350 non-null    int64
# dtypes: float64(2), int64(9), object(1)
# memory usage: 32.9+ KB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22468 entries, 0 to 22467
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  22468 non-null  int64
#  1   STATE                       22468 non-null  object
#  2   Year                        22468 non-null  int64
#  3   CO2                         22468 non-null  int64
#  4   CH4                         22468 non-null  int64
#  5   N2O                         22468 non-null  int64
#  6   Fluorinated GHG             22468 non-null  int64
#  7   Laws and Regulations        22468 non-null  int64
#  8   State Incentives            22468 non-null  int64
#  9   Utility/Private Incentives  22468 non-null  int64
#  10  Ozone                       22468 non-null  float64
#  11  Question                    22416 non-null  object
#  12  DataValue                   17119 non-null  float64
# ...

# %%
clusresult[50:100]
# Out:
#     Unnamed: 0 STATE  Year        CO2      CH4       N2O  Fluorinated GHG  \
# 50          50    DE  2013    7932200   320105     16742              NaN
# 51          51    DE  2014    7798501   374321     13222              NaN
# 52          52    DE  2015    7547438   502657     13336              NaN
# 53          53    DE  2016    7832062   496746     14045              NaN
# 54          54    DE  2017    6560049   488161     10194              NaN
# 55          55    DE  2018    6578229   439430     11025              NaN
# 56          56    FL  2012  120645361  6901194   5739976              NaN
# 57          57    FL  2013  118084663  6606354   4501029              NaN
# 58          58    FL  2014  123269319  6671539   4994554              NaN
# 59          59    FL  2015  122278676  6564558   4080300              NaN
# 60          60    FL  2016  119934078  6872800   7524030              NaN
# 61          61    FL  2017  117113291  7406817   7748239              NaN
# ...

# %% [markdown]
# ## Dropping unwanted columns

# %%
df = clusresult.drop(columns=['Unnamed: 0','CO2','CH4','N2O','Fluorinated GHG','Laws and Regulations','State Incentives','Utility/Private Incentives',
                              'Ozone'])

# %%
df.head()
# Out:
#   STATE  Year  cluster
# 0    AL  2012        1
# 1    AL  2013        1
# 2    AL  2014        1
# 3    AL  2015        1
# 4    AL  2016        1

# %%
data[150:200]
# Out:
#     STATE  Year       CO2     CH4     N2O  Fluorinated GHG  \
# 150    AL  2014  84847355  634009  525399           312201
# 151    AL  2014  84847355  634009  525399           312201
# 152    AL  2014  84847355  634009  525399           312201
# 153    AL  2014  84847355  634009  525399           312201
# 154    AL  2014  84847355  634009  525399           312201
# 155    AL  2014  84847355  634009  525399           312201
# 156    AL  2014  84847355  634009  525399           312201
# 157    AL  2014  84847355  634009  525399           312201
# 158    AL  2014  84847355  634009  525399           312201
# 159    AL  2014  84847355  634009  525399           312201
# 160    AL  2014  84847355  634009  525399           312201
# 161    AL  2014  84847355  634009  525399           312201
# 162    AL  2014  84847355  634009  525399           312201
# 163    AL  2014  84847355  634009  525399           312201
# 164    AL  2014  84847355  634009  525399           312201
# ...

# %%
df_final = pd.merge(
                     
                     df,data,
                     how  = 'left', on = ['STATE','Year'])

# %%
df_final.head()
# Out:
#   STATE  Year  cluster       CO2     CH4     N2O  Fluorinated GHG  \
# 0    AL  2012        1  84138381  701702  602778           264437
# 1    AL  2012        1  84138381  701702  602778           264437
# 2    AL  2012        1  84138381  701702  602778           264437
# 3    AL  2012        1  84138381  701702  602778           264437
# 4    AL  2012        1  84138381  701702  602778           264437
#
#    Laws and Regulations  State Incentives  Utility/Private Incentives  \
# 0                     3                 7                           4
# 1                     3                 7                           4
# 2                     3                 7                           4
# 3                     3                 7                           4
# 4                     3                 7                           4
#
#       Ozone                              Question  DataValue  \
# 0  0.044215  Mortality from diseases of the heart      234.8
# ...

# %% [markdown]
# ## Reading State data containing region number and name

# %%
division = pd.read_csv("statdata.csv")

# %%
division.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   REGION       51 non-null     int64
#  1   STATE        51 non-null     object
#  2   Region_Name  51 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %%
division[1:15]
# Out:
#     REGION STATE       Region_Name
# 1        4    AK       West Region
# 2        4    AZ       West Region
# 3        3    AR      South Region
# 4        4    CA       West Region
# 5        4    CO       West Region
# 6        1    CT  Northeast Region
# 7        3    DE      South Region
# 8        3    DC      South Region
# 9        3    FL      South Region
# 10       3    GA      South Region
# 11       4    HI       West Region
# 12       4    ID       West Region
# 13       2    IL    Midwest Region
# 14       2    IN    Midwest Region

# %%
df_final = pd.merge(
                     
                     df_final,division,
                     how  = 'left', on = ['STATE'])

# %%
df_final[150:200]
# Out:
#     STATE  Year  cluster       CO2     CH4     N2O  Fluorinated GHG  \
# 150    AL  2013        1  83297945  594388  451420           274194
# 151    AL  2013        1  83297945  594388  451420           274194
# 152    AL  2014        1  84847355  634009  525399           312201
# 153    AL  2014        1  84847355  634009  525399           312201
# 154    AL  2014        1  84847355  634009  525399           312201
# 155    AL  2014        1  84847355  634009  525399           312201
# 156    AL  2014        1  84847355  634009  525399           312201
# 157    AL  2014        1  84847355  634009  525399           312201
# 158    AL  2014        1  84847355  634009  525399           312201
# 159    AL  2014        1  84847355  634009  525399           312201
# 160    AL  2014        1  84847355  634009  525399           312201
# 161    AL  2014        1  84847355  634009  525399           312201
# 162    AL  2014        1  84847355  634009  525399           312201
# ...

# %% [markdown]
# ## Creating merged dataset file from the python notebook

# %%
df_final.to_csv('finaldata_clusters_regions_Added.csv')
