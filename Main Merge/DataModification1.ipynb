# %%
import pandas as pd
final = pd.read_csv('US_Chronic_Disease_Indicators.csv')

# %%
final.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource      Topic  \
# 0       2018     2018           AL      Alabama      BRFSS    Alcohol
# 1       2011     2011           AL      Alabama      BRFSS  Arthritis
# 2       2018     2018           AL      Alabama      BRFSS  Arthritis
# 3       2018     2018           AL      Alabama      BRFSS     Cancer
# 4       2018     2018           AL      Alabama      BRFSS     Cancer
#
#                                             Question  Response DataValueUnit  \
# 0       Heavy drinking among adults aged >= 18 years       NaN             %
# 1            Arthritis among adults aged >= 18 years       NaN             %
# 2  Fair or poor health among adults aged >= 18 ye...       NaN             %
# 3  Recent Papanicolaou smear use among women aged...       NaN             %
# 4  Papanicolaou smear use among adult women aged ...       NaN             %
#
#              DataValueType  ... LocationID  TopicID QuestionID  \
# ...

# %%
final_modified_datasource = final.loc[(final['DataSource'] == 'NVSS') | (final['DataSource'] == 'Statewide central cancer registries')]
final_modified_datasource.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172848 entries, 5 to 814936
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  172848 non-null  int64
#  1   YearEnd                    172848 non-null  int64
#  2   LocationAbbr               172848 non-null  object
#  3   LocationDesc               172848 non-null  object
#  4   DataSource                 172848 non-null  object
#  5   Topic                      172848 non-null  object
#  6   Question                   172848 non-null  object
#  7   Response                   0 non-null       float64
#  8   DataValueUnit              128729 non-null  object
#  9   DataValueType              172848 non-null  object
#  10  DataValue                  129831 non-null  object
#  11  DataValueAlt               129831 non-null  float64
#  12  DataValueFootnoteSymbol    43017 non-null   object
# ...

# %%
final_modified_datasource = final_modified_datasource.loc[(final_modified_datasource['YearStart'] == 2012)|(final_modified_datasource['YearStart'] == 2013) |(final_modified_datasource['YearStart'] == 2014)|(final_modified_datasource['YearStart'] == 2015)|(final_modified_datasource['YearStart'] == 2016)|(final_modified_datasource['YearStart'] == 2017)|(final_modified_datasource['YearStart'] == 2018)]
final_modified_datasource.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104754 entries, 5 to 811742
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  104754 non-null  int64
#  1   YearEnd                    104754 non-null  int64
#  2   LocationAbbr               104754 non-null  object
#  3   LocationDesc               104754 non-null  object
#  4   DataSource                 104754 non-null  object
#  5   Topic                      104754 non-null  object
#  6   Question                   104754 non-null  object
#  7   Response                   0 non-null       float64
#  8   DataValueUnit              83333 non-null   object
#  9   DataValueType              104754 non-null  object
#  10  DataValue                  77781 non-null   object
#  11  DataValueAlt               77781 non-null   float64
#  12  DataValueFootnoteSymbol    26973 non-null   object
# ...

# %%
final_modified_datasource = final_modified_datasource.loc[(final_modified_datasource['Topic'] == 'Overarching Conditions') |(final_modified_datasource['Topic'] == 'Asthma') |(final_modified_datasource['Topic'] == 'Cardiovascular Disease') | (final_modified_datasource['Topic'] == 'Cancer') | (final_modified_datasource['Topic'] == 'Chronic Obstructive Pulmonary Disease')]
final_modified_datasource.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75306 entries, 23 to 811742
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  75306 non-null  int64
#  1   YearEnd                    75306 non-null  int64
#  2   LocationAbbr               75306 non-null  object
#  3   LocationDesc               75306 non-null  object
#  4   DataSource                 75306 non-null  object
#  5   Topic                      75306 non-null  object
#  6   Question                   75306 non-null  object
#  7   Response                   0 non-null      float64
#  8   DataValueUnit              60020 non-null  object
#  9   DataValueType              75306 non-null  object
#  10  DataValue                  57993 non-null  object
#  11  DataValueAlt               57993 non-null  float64
#  12  DataValueFootnoteSymbol    17313 non-null  object
# ...

# %%
final_modified_datasource = final_modified_datasource.loc[(final_modified_datasource['Question'] == 'Asthma mortality rate') | (final_modified_datasource['Question'] == 'Cancer of the lung and bronchus, incidence') | (final_modified_datasource['Question'] == 'Invasive cancer (all sites combined), incidence') | (final_modified_datasource['Question'] == 'Mortality from coronary heart disease') | (final_modified_datasource['Question'] == 'Mortality from diseases of the heart') | (final_modified_datasource['Question'] == 'Mortality from heart failure') | (final_modified_datasource['Question'] == 'Mortality from total cardiovascular diseases') | (final_modified_datasource['Question'] == 'Mortality with chronic obstructive pulmonary disease as underlying cause among adults aged >= 45 years') | (final_modified_datasource['Question'] == 'Mortality with chronic obstructive pulmonary disease as underlying or contributing cause among adults aged >= 45 years')| (final_modified_datasource['Question'] == 'Premature mortality among adults aged 45-64 years')]

# %%
final_modified_datasource.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61392 entries, 23 to 811742
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  61392 non-null  int64
#  1   YearEnd                    61392 non-null  int64
#  2   LocationAbbr               61392 non-null  object
#  3   LocationDesc               61392 non-null  object
#  4   DataSource                 61392 non-null  object
#  5   Topic                      61392 non-null  object
#  6   Question                   61392 non-null  object
#  7   Response                   0 non-null      float64
#  8   DataValueUnit              49517 non-null  object
#  9   DataValueType              61392 non-null  object
#  10  DataValue                  47325 non-null  object
#  11  DataValueAlt               47325 non-null  float64
#  12  DataValueFootnoteSymbol    14067 non-null  object
# ...

# %%
final_modified_datasource = final_modified_datasource.loc[(final_modified_datasource['DataValueType'] == 'Crude Rate') | (final_modified_datasource['DataValueType'] == 'Average Annual Crude Rate')]

# %%
final_modified_datasource.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20464 entries, 68 to 811742
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  20464 non-null  int64
#  1   YearEnd                    20464 non-null  int64
#  2   LocationAbbr               20464 non-null  object
#  3   LocationDesc               20464 non-null  object
#  4   DataSource                 20464 non-null  object
#  5   Topic                      20464 non-null  object
#  6   Question                   20464 non-null  object
#  7   Response                   0 non-null      float64
#  8   DataValueUnit              20464 non-null  object
#  9   DataValueType              20464 non-null  object
#  10  DataValue                  15775 non-null  object
#  11  DataValueAlt               15775 non-null  float64
#  12  DataValueFootnoteSymbol    4689 non-null   object
# ...

# %%
final_modified_datasource.to_csv('new_final_modified_datasource.csv')
