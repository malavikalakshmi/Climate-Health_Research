# %%
import pandas as pd
targetdata = pd.read_csv('new_final_modified_target.csv')

targetdata = targetdata.drop(['Unnamed: 0'], axis=1)

gasesandchemicals = pd.read_csv('final data 0802.csv')

# %%
targetdata.head()
targetdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20464 entries, 0 to 20463
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     20464 non-null  int64
#  1   STATE                    20464 non-null  object
#  2   Question                 20464 non-null  object
#  3   DataValue                15775 non-null  float64
#  4   StratificationCategory1  20464 non-null  object
#  5   Stratification1          20464 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 959.4+ KB

# %%
gasesandchemicals.head()
# Out:
#   STATE  Year       CO2     CH4     N2O  Fluorinated GHG  Incentives  \
# 0    AL  2012  84138381  701702  602778           264437           0
# 1    AL  2013  83297945  594388  451420           274194           0
# 2    AL  2014  84847355  634009  525399           312201           0
# 3    AL  2015  82143007  611595  462661           263031           0
# 4    AL  2016  75103394  550119  528136           302584           0
#
#    Laws and Regulations  State Incentives  Utility/Private Incentives  \
# 0                     3                 7                           4
# 1                     3                 7                           4
# 2                     3                 7                           4
# 3                     3                 7                           3
# 4                     3                 6                           2
#
#    Programs  State Hybrid Incentives     Ozone
# 0         0                        0  0.044215
# ...

# %%
newdata = gasesandchemicals.merge(targetdata,  how  = 'outer',on=['STATE', 'Year'])

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20914 entries, 0 to 20913
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   STATE                       20914 non-null  object
#  1   Year                        20914 non-null  int64
#  2   CO2                         20050 non-null  float64
#  3   CH4                         20050 non-null  float64
#  4   N2O                         20050 non-null  float64
#  5   Fluorinated GHG             20050 non-null  float64
#  6   Incentives                  20050 non-null  float64
#  7   Laws and Regulations        20050 non-null  float64
#  8   State Incentives            20050 non-null  float64
#  9   Utility/Private Incentives  20050 non-null  float64
#  10  Programs                    20050 non-null  float64
#  11  State Hybrid Incentives     20050 non-null  float64
#  12  Ozone                       20050 non-null  float64
# ...

# %%
newdata[0:20]
# Out:
#    STATE  Year         CO2       CH4       N2O  Fluorinated GHG  Incentives  \
# 0     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 1     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 2     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 3     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 4     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 5     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 6     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 7     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 8     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 9     AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# 10    AL  2012  84138381.0  701702.0  602778.0         264437.0         0.0
# ...

# %%
newdata.to_csv('new_final_target_predictors_added.csv')
